# %% [markdown]
# #### The NYC Permitted Event Information dataset contains information on approved event applications that will take place in the next month. <br> And I'm working to identify how each event relates to each station from the MTA datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def concant(weeks):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    
    dfs = []
    for i in weeks:
        url_file = url.format(i)
        print(url_file)
        dfs.append(pd.read_csv(url_file))
    return pd.concat(dfs)

# %%
from datetime import datetime, timedelta

def generate_dates (sdate):
    dates = pd.date_range(sdate,pd.to_datetime("today")-timedelta(days=1),freq='w-sat')
    weeks = [i.strftime('%y%m%d') for i in list(dates)]

    return concant(weeks)

# %%
df = generate_dates('2021-06-27')
# Out:
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210703.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210710.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210717.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210724.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210731.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210807.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210814.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210821.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210828.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210904.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210911.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210918.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_210925.txt

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/26/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/26/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/26/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/26/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/26/2021  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7592792
# 1  REGULAR  7592804
# 2  REGULAR  7592816
# 3  REGULAR  7592870
# 4  REGULAR  7592992
#
#    EXITS
# 0                                            2595706
# 1                                            2595713
# 2                                            2595729
# 3                                            2595762
# 4                                            2595791

# %%
df.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
df['DATE'] = df['DATE'].apply(pd.to_datetime)
df['DATE'].head()
# Out:
# 0   2021-06-26
# 1   2021-06-26
# 2   2021-06-26
# 3   2021-06-26
# 4   2021-06-26
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# ##### Read NYC events dataset

# %%
df_event = pd.read_csv("NYC_Permitted_Event_Information.csv")
df_event['Start Date/Time']
# Out:
# 0        10/20/2021 12:00:00 PM
# 1        10/12/2021 03:00:00 PM
# 2        10/15/2021 12:00:00 PM
# 3        10/22/2021 10:00:00 AM
# 4        10/21/2021 12:01:00 AM
#                   ...
# 26062    10/17/2021 07:00:00 AM
# 26063    10/17/2021 10:00:00 AM
# 26064    10/17/2021 08:00:00 AM
# 26065    10/17/2021 09:00:00 AM
# 26066    10/16/2021 10:00:00 AM
# Name: Start Date/Time, Length: 26067, dtype: object

# %% [markdown]
# ##### Find the percentage of missing values in each column in the event dataset

# %%
for col in df_event.columns:
    pct_missing = np.mean(df_event[col].isna())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Event ID - 0%
# Event Name - 0%
# Start Date/Time - 0%
# End Date/Time - 0%
# Event Agency - 0%
# Event Type - 0%
# Event Borough - 0%
# Event Location - 0%
# Event Street Side - 97%
# Street Closure Type - 97%
# Community Board - 0%
# Police Precinct - 0%

# %% [markdown]
# ##### Drop columns with missing values

# %%
df_event.columns
# Out:
# Index(['Event ID', 'Event Name', 'Start Date/Time', 'End Date/Time',
#        'Event Agency', 'Event Type', 'Event Borough', 'Event Location',
#        'Event Street Side', 'Street Closure Type', 'Community Board',
#        'Police Precinct'],
#       dtype='object')

# %%
df_event = df_event.drop(labels=['Event Street Side','Street Closure Type'],axis=1)
df_event.columns
# Out:
# Index(['Event ID', 'Event Name', 'Start Date/Time', 'End Date/Time',
#        'Event Agency', 'Event Type', 'Event Borough', 'Event Location',
#        'Community Board', 'Police Precinct'],
#       dtype='object')

# %% [markdown]
# ##### Checking the type of each column

# %%
df_event.dtypes
# Out:
# Event ID            int64
# Event Name         object
# Start Date/Time    object
# End Date/Time      object
# Event Agency       object
# Event Type         object
# Event Borough      object
# Event Location     object
# Community Board    object
# Police Precinct    object
# dtype: object

# %% [markdown]
# ##### Convert Start and End date to datetime objects

# %%
df_event[['Start Date/Time','End Date/Time']] = df_event[['Start Date/Time','End Date/Time']].apply(pd.to_datetime)

# %%
df_event.dtypes
# Out:
# Event ID                    int64
# Event Name                 object
# Start Date/Time    datetime64[ns]
# End Date/Time      datetime64[ns]
# Event Agency               object
# Event Type                 object
# Event Borough              object
# Event Location             object
# Community Board            object
# Police Precinct            object
# dtype: object

# %%
df_event['Start Date'] = df_event['Start Date/Time'].dt.date
df_event['Start Date']
# Out:
# 0        2021-10-20
# 1        2021-10-12
# 2        2021-10-15
# 3        2021-10-22
# 4        2021-10-21
#             ...
# 26062    2021-10-17
# 26063    2021-10-17
# 26064    2021-10-17
# 26065    2021-10-17
# 26066    2021-10-16
# Name: Start Date, Length: 26067, dtype: object

# %%
df_event# df_event[df_event["Start Date"].astype(str) == "2021-10-20"]
# Out:
#        Event ID                     Event Name     Start Date/Time  \
# 0        598895              Baseball - Adults 2021-10-20 12:00:00
# 1        581423        Soccer - Non Regulation 2021-10-12 15:00:00
# 2        589278        Soccer - Non Regulation 2021-10-15 12:00:00
# 3        585078             Soccer -Regulation 2021-10-22 10:00:00
# 4        590861  Lawn Closure of Veterans lawn 2021-10-21 00:01:00
# ...         ...                            ...                 ...
# 26062    590584        Soccer - Non Regulation 2021-10-17 07:00:00
# 26063    582523             Soccer -Regulation 2021-10-17 10:00:00
# 26064    571383             Soccer -Regulation 2021-10-17 08:00:00
# 26065    585841               Football - Youth 2021-10-17 09:00:00
# 26066    570915             Soccer -Regulation 2021-10-16 10:00:00
#
#             End Date/Time      Event Agency     Event Type  Event Borough  \
# 0     2021-10-20 17:00:00  Parks Department  Sport - Adult          Bronx
# 1     2021-10-12 18:00:00  Parks Department  Sport - Youth       Brooklyn
# 2     2021-10-15 17:30:00  Parks Department  Sport - Youth  Staten Island
# 3     2021-10-22 11:30:00  Parks Department  Sport - Youth      Manhattan
# 4     2021-10-21 23:00:00  Parks Department  Special Event      Manhattan
# ...                   ...               ...            ...            ...
# 26062 2021-10-17 19:00:00  Parks Department  Sport - Youth         Queens
# 26063 2021-10-17 14:00:00  Parks Department  Sport - Youth      Manhattan
# 26064 2021-10-17 23:00:00  Parks Department  Sport - Youth      Manhattan
# 26065 2021-10-17 22:00:00  Parks Department  Sport - Youth       Brooklyn
# 26066 2021-10-16 18:00:00  Parks Department  Sport - Adult      Manhattan
#
#                                           Event Location  \
# 0                Van Cortlandt Park: Stadium-Baseball-01
# 1      Bush Terminal Park: Soccer-02 ,Bush Terminal P...
# 2              Fairview Park: Multi-Purpose Play Area-01
# 3      Randall's Island Park: Wards Meadow Fields-Soc...
# 4                     Madison Square Park: Veterans Lawn
# ...                                                  ...
# 26062  Queensbridge Park: Multi Purpose Play Area-01 ...
# 26063  Randall's Island Park: East River Fields-Socce...
# 26064  Randall's Island Park: East River Fields-Socce...
# 26065                           McCarren Park: Soccer-01
# 26066  Randall's Island Park: Wards Meadow Fields-Soc...
#
#                Community Board          Police Precinct  Start Date
# 0                          26,                      50,  2021-10-20
# 1      01, 07, 08, 10, 13, 16,  60, 68, 72, 73, 77, 94,  2021-10-12
# 2                           3,                     123,  2021-10-15
# 3                          11,                      25,  2021-10-22
# 4                           5,                      13,  2021-10-21
# ...                        ...                      ...         ...
# 26062                   01, 5,                104, 114,  2021-10-17
# 26063                      11,                      25,  2021-10-17
# 26064                      11,                      25,  2021-10-17
# 26065                      01,                      94,  2021-10-17
# 26066                      11,                      25,  2021-10-16
#
# [26067 rows x 11 columns]

# %%
mask = (df_event["Start Date"] > pd.Timestamp('2021-06-27')) & (df_event["Start Date"] <= pd.Timestamp('2021-09-27'))

df_event_range = df_event.loc[mask]
df_event_range = df_event_range.sort_values(by='Start Date')
df_event_range
# Out:
# /Users/noramofeed/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#        Event ID                                Event Name     Start Date/Time  \
# 15703    587174                  MoMA PS1 Temporary Plaza 2021-07-03 12:00:00
# 25663    592648               Covid-19 Vaccination center 2021-07-21 00:00:00
# 25132    592645               Covid-19 Vaccination Center 2021-07-21 00:00:00
# 20421    595822  Mobile COVID-19 Testing and Vaccine Site 2021-08-06 08:00:00
# 705      598263  Mobile COVID-19 Testing and Vaccine Site 2021-08-17 11:00:00
# ...         ...                                       ...                 ...
# 7962     579505                   Soccer - Non Regulation 2021-09-27 08:00:00
# 4004     571557                   Soccer - Non Regulation 2021-09-27 18:00:00
# 14712    597786                                    Tennis 2021-09-27 15:30:00
# 13199    578619                                Basketball 2021-09-27 08:00:00
# 8068     581994           Football Ã¢â¬â Flag Football 2021-09-27 08:00:00
#
#             End Date/Time                   Event Agency        Event Type  \
# 15703 2021-10-31 18:00:00  Street Activity Permit Office      Street Event
# 25663 2021-10-03 00:00:00  Street Activity Permit Office  Production Event
# 25132 2021-10-03 00:00:00  Street Activity Permit Office  Production Event
# 20421 2021-10-09 19:00:00  Street Activity Permit Office      Street Event
# 705   2021-10-10 19:00:00  Street Activity Permit Office      Street Event
# ...                   ...                            ...               ...
# 7962  2021-09-27 22:00:00               Parks Department     Sport - Youth
# 4004  2021-09-27 20:00:00               Parks Department     Sport - Youth
# 14712 2021-09-27 17:30:00               Parks Department     Sport - Youth
# 13199 2021-09-27 18:00:00               Parks Department     Sport - Youth
# 8068  2021-09-27 20:00:00               Parks Department     Sport - Youth
#
#       Event Borough                                     Event Location  \
# 15703        Queens     46 AVENUE between 46 AVENUE and JACKSON AVENUE
# 25663      Brooklyn  ROGERS AVENUE between FOSTER AVENUE and FARRAG...
# 25132      Brooklyn  WILLIAMS AVENUE between LIVONIA AVENUE and RIV...
# 20421     Manhattan     WEST   42 STREET between 8 AVENUE and 9 AVENUE
# 705       Manhattan     WEST   34 STREET between 7 AVENUE and 8 AVENUE
# ...             ...                                                ...
# 7962       Brooklyn  Bill Brown Playground: Soccer-01 ,Calvert Vaux...
# 4004         Queens                          Big Bush Park: Soccer-01
# 14712        Queens  Bayswater Park: Tennis-01 ,Bayswater Park: Ten...
# 13199        Queens  Triborough Bridge Playground B: Basketball-01 ...
# 8068       Brooklyn                      Bath Beach Park: Football-01
#
#       Community Board Police Precinct  Start Date
# 15703              2,            108,  2021-07-03
# 25663             14,             70,  2021-07-21
# 25132              5,             75,  2021-07-21
# 20421              4,             14,  2021-08-06
# 705             4, 5,             14,  2021-08-17
# ...               ...             ...         ...
# 7962         13, 15,         60, 61,   2021-09-27
# 4004             02,            108,   2021-09-27
# 14712            14,            101,   2021-09-27
# 13199         01, 04,       110, 114,  2021-09-27
# 8068             11,             62,   2021-09-27
#
# [4883 rows x 11 columns]

# %%
df_event_range['Start Date'] = df_event_range['Start Date'].apply(pd.to_datetime)

# %% [markdown]
# #### Most type of event type in each month -Within the 3 months- (Stack bar) (X-axis = Months, Y-axis = Event type)

# %%
# Most type of event type in each month -Within the 3 months- (Stack bar) (X-axis = Months, Y-axis = Event type)

## renaming it is required

date_range = pd.date_range(start='2021-06-27', end='2021-09-27',freq='M')
print(date_range)
most_event_type = df_event_range.groupby([df_event_range['Start Date'].dt.month, 'Event Type'])['Event Type'].count()
most_event_type = pd.DataFrame(most_event_type)
most_event_type = most_event_type.rename({'Event Type' : 'Count' , 'Start Date' : 'Month'},axis=1)
print(most_event_type.columns)
most_event_type
# Out:
# DatetimeIndex(['2021-06-30', '2021-07-31', '2021-08-31'], dtype='datetime64[ns]', freq='M')
# Index(['Count'], dtype='object')
#                                            Count
# Start Date Event Type
# 7          Production Event                    2
#            Street Event                        1
# 8          Block Party                         1
#            Religious Event                     9
#            Street Event                        5
#            Theater Load in and Load Outs       1
# 9          Athletic Race / Tour                6
#            Block Party                        49
#            Farmers Market                     45
#            Health Fair                         4
#            Open Culture                        4
#            Parade                              8
#            Plaza Event                        15
#            Plaza Partner Event                11
#            Production Event                   23
#            Rally                               1
#            Religious Event                    36
#            Rigging Permit                      1
#            Sidewalk Sale                       9
#            Single Block Festival               8
#            Special Event                    1030
#            Sport - Adult                     850
#            Sport - Youth                    2657
#            Stickball                           1
#            Street Event                       77
#            Street Festival                     6
#            Theater Load in and Load Outs      16
#            Theater Load in and Load Outs       7

# %%
indexed_most_event_type = most_event_type.reset_index()
indexed_most_event_type = indexed_most_event_type.rename({'Start Date' : 'Month'},axis=1)
indexed_most_event_type['Month'] = indexed_most_event_type['Month'].replace({7:'July',8:'August',9:'September '})
indexed_most_event_type
# s = sns.barplot(x ="Month", y = 'Event Type', data = indexed_most_event_type)



plt.bar(x = indexed_most_event_type['Event Type'], y =indexed_most_event_type['Count'], height=10)
plt.xticks(rotation='90');
# Out:
# /Users/noramofeed/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#
# TypeError: cannot convert the series to <class 'float'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/yh/4m90rwdj6ng3b7vw1f6fl6qw0000gn/T/ipykernel_7072/2716150702.py in <module>
#       7
#       8
# ----> 9 plt.bar(x = indexed_most_event_type['Event Type'], y =indexed_most_event_type['Count'], height=10)
#      10 plt.xticks(rotation='90');
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2369             elif orientation == 'horizontal':
#    2370                 r.sticky_edges.x.append(l)
# -> 2371             self.add_patch(r)
#    2372             patches.append(r)
#    2373
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2168         if p.get_clip_path() is None:
#    2169             p.set_clip_path(self.patch)
# -> 2170         self._update_patch_limits(p)
#    2171         self.patches.append(p)
#    2172         p._remove_method = self.patches.remove
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2190             p.codes, (mpath.Path.CLOSEPOLY, mpath.Path.STOP), invert=True)]
#    2191         if vertices.size > 0:
# -> 2192             xys = patch.get_patch_transform().transform(vertices)
#    2193             if patch.get_data_transform() != self.transData:
#    2194                 patch_to_data = (patch.get_data_transform() -
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     775         # important to call the accessor method and not directly access the
#     776         # transformation member variable.
# --> 777         bbox = self.get_bbox()
#     778         return (transforms.BboxTransformTo(bbox)
#     779                 + transforms.Affine2D().rotate_deg_around(
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/patches.py in get_bbox(self)
#     855         """Return the `.Bbox`."""
#     856         x0, y0, x1, y1 = self._convert_units()
# --> 857         return transforms.Bbox.from_extents(x0, y0, x1, y1)
#     858
#     859     xy = property(get_xy, set_xy)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in from_extents(minpos, *args)
#     844            scales where negative bounds result in floating point errors.
#     845         """
# --> 846         bbox = Bbox(np.reshape(args, (2, 2)))
#     847         if minpos is not None:
#     848             bbox._minpos[:] = minpos
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in __init__(self, points, **kwargs)
#     786         """
#     787         super().__init__(**kwargs)
# --> 788         points = np.asarray(points, float)
#     789         if points.shape != (2, 2):
#     790             raise ValueError('Bbox points must be of the form '
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: setting an array element with a sequence.

# %%
# print(df_event[df_event['Start Date'] == '2021-10-20']['Event Type'])
# df_event.loc[df_event['Start Date'] == '2021-10-20']

# %%
for col in df_event.columns:
    pct_missing = np.mean(df_event[col].isna())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Event ID - 0%
# Event Name - 0%
# Start Date/Time - 0%
# End Date/Time - 0%
# Event Agency - 0%
# Event Type - 0%
# Event Borough - 0%
# Event Location - 0%
# Community Board - 0%
# Police Precinct - 0%
# Start Date - 0%

# %%
event_locations = df_event['Event Location'].unique()
#print(sorted(locations))
print(len(event_locations))
# Out:
# 3523

# %%
df_event["Event Type"] = df_event["Event Type"].str.strip(' ')
event_type = df_event["Event Type"].unique()
print(event_type)
# Out:
# ['Sport - Adult' 'Sport - Youth' 'Special Event' 'Farmers Market'
#  'Religious Event' 'Street Event' 'Block Party' 'Production Event'
#  'Open Culture' 'Parade' 'Stickball' 'Shooting Permit' 'Plaza Event'
#  'Sidewalk Sale' 'Theater Load in and Load Outs' 'Press Conference'
#  'Single Block Festival' 'Athletic Race / Tour' 'Health Fair'
#  'Plaza Partner Event' 'Rigging Permit' 'Street Festival' 'Rally']

# %%
events_date = df_event_range['Start Date/Time'].dt.date.value_counts()
events_date
# Out:
# 2021-09-25    1299
# 2021-09-26    1071
# 2021-09-23     860
# 2021-09-24     808
# 2021-09-27     748
# 2021-09-20      24
# 2021-09-22      10
# 2021-09-19       6
# 2021-09-07       6
# 2021-09-06       5
# 2021-09-17       4
# 2021-09-21       4
# 2021-08-27       4
# 2021-08-26       4
# 2021-09-14       3
# 2021-09-16       3
# 2021-09-18       2
# 2021-09-15       2
# 2021-09-09       2
# 2021-07-21       2
# 2021-09-01       2
# 2021-08-31       2
# 2021-08-29       2
# 2021-09-12       1
# 2021-09-10       1
# 2021-09-04       1
# 2021-09-03       1
# 2021-09-02       1
# 2021-08-28       1
# 2021-08-24       1
# 2021-08-17       1
# 2021-08-06       1
# 2021-07-03       1
# Name: Start Date/Time, dtype: int64

# %%
events_date.shape
# Out:
# (33,)

# %%
# plt.plot(events_date)
events_date_plot = events_date.plot(kind='pie', figsize=(10,10),autopct='%1.0f%%')
events_date.to_csv('events_date.csv')

# %%
grouped_by_date = df_event_range.groupby(df_event_range['Start Date'])["Event Type"].count()

# %%
grouped_by_date = pd.DataFrame(grouped_by_date)
grouped_by_date = grouped_by_date.sort_values('Start Date')
grouped_by_date
# Out:
#             Event Type
# Start Date
# 2021-07-03           1
# 2021-07-21           2
# 2021-08-06           1
# 2021-08-17           1
# 2021-08-24           1
# 2021-08-26           4
# 2021-08-27           4
# 2021-08-28           1
# 2021-08-29           2
# 2021-08-31           2
# 2021-09-01           2
# 2021-09-02           1
# 2021-09-03           1
# 2021-09-04           1
# 2021-09-06           5
# 2021-09-07           6
# 2021-09-09           2
# 2021-09-10           1
# 2021-09-12           1
# 2021-09-14           3
# 2021-09-15           2
# 2021-09-16           3
# 2021-09-17           4
# 2021-09-18           2
# 2021-09-19           6
# 2021-09-20          24
# 2021-09-21           4
# 2021-09-22          10
# 2021-09-23         860
# 2021-09-24         808
# 2021-09-25        1299
# 2021-09-26        1071
# 2021-09-27         748

# %%
boroughs = df_event_range['Event Borough'].unique()
boroughs
# Out:
# array(['Queens', 'Brooklyn', 'Manhattan', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
events_type_count = df_event_range["Event Type"].value_counts()
events_type_count
# Out:
# Sport - Youth                     2657
# Special Event                     1030
# Sport - Adult                      850
# Street Event                        83
# Block Party                         50
# Farmers Market                      45
# Religious Event                     45
# Production Event                    25
# Theater Load in and Load Outs       17
# Plaza Event                         15
# Plaza Partner Event                 11
# Sidewalk Sale                        9
# Single Block Festival                8
# Parade                               8
# Theater Load in and Load Outs        7
# Street Festival                      6
# Athletic Race / Tour                 6
# Open Culture                         4
# Health Fair                          4
# Rigging Permit                       1
# Rally                                1
# Stickball                            1
# Name: Event Type, dtype: int64

# %%
brooklyn_grouped_by = df_event_range[df_event_range['Event Borough'] == 'Brooklyn'].groupby(['Event Borough'])['Event Type'].value_counts()
df_brooklyn_grouped_by = pd.DataFrame(brooklyn_grouped_by)
df_brooklyn_grouped_by = df_brooklyn_grouped_by.rename({'Event Type': 'Count'},axis=1)
df_brooklyn_grouped_by
# df_brooklyn_grouped_by = df_brooklyn_grouped_by.sort_values(ascending=False)
# Out:
#                                      Count
# Event Borough Event Type
# Brooklyn      Sport - Youth            699
#               Special Event            216
#               Sport - Adult            159
#               Block Party               37
#               Religious Event           32
#               Street Event              27
#               Farmers Market            13
#               Production Event           5
#               Plaza Partner Event        4
#               Athletic Race / Tour       2
#               Open Culture               1
#               Parade                     1
#               Plaza Event                1
#               Rigging Permit             1
#               Single Block Festival      1
#               Street Festival            1

# %% [markdown]
# #### Check the shape

# %%
indexed_df_brooklyn_grouped_by = df_brooklyn_grouped_by.reset_index()

data = indexed_df_brooklyn_grouped_by['Count']
labels = indexed_df_brooklyn_grouped_by['Event Type']

# #define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]


# #create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.tight_layout()

plt.show()


indexed_df_brooklyn_grouped_by.to_csv('indexed_df_brooklyn_grouped_by.csv')

# %%
df_brooklyn_grouped_by_plot = df_brooklyn_grouped_by.plot.barh(title="Brooklyn - Event Types");
plt.savefig('df_brooklyn_grouped_by_plot.png', dpi=300, bbox_inches='tight')

# %%
manhattan_grouped_by = df_event_range[df_event_range['Event Borough'] == 'Manhattan'].groupby(['Event Borough'])['Event Type'].value_counts()
df_manhattan_grouped_by = pd.DataFrame(manhattan_grouped_by)
df_manhattan_grouped_by = df_manhattan_grouped_by.rename({'Event Type': 'Count'},axis=1)
df_manhattan_grouped_by.sort_values(by='Count', ascending=False)
# Out:
#                                               Count
# Event Borough Event Type
# Manhattan     Sport - Youth                     921
#               Sport - Adult                     389
#               Special Event                     369
#               Street Event                       28
#               Farmers Market                     20
#               Production Event                   20
#               Theater Load in and Load Outs      17
#               Religious Event                    12
#               Plaza Event                         8
#               Theater Load in and Load Outs       7
#               Plaza Partner Event                 7
#               Sidewalk Sale                       5
#               Single Block Festival               4
#               Street Festival                     4
#               Parade                              3
#               Athletic Race / Tour                2
#               Block Party                         2
#               Health Fair                         2
#               Open Culture                        2
#               Rally                               1

# %%
df_manhattan_grouped_by.plot.barh(title=" Manhattan - Event Types");

# %%
queens_grouped_by = df_event_range[df_event_range['Event Borough'] == 'Queens'].groupby(['Event Borough'])['Event Type'].value_counts()
df_queens_grouped_by = pd.DataFrame(queens_grouped_by)
df_queens_grouped_by = df_queens_grouped_by.rename({'Event Type': 'Count'},axis=1)
df_queens_grouped_by.sort_values(by='Count', ascending=False)
# Out:
#                                      Count
# Event Borough Event Type
# Queens        Sport - Youth            543
#               Sport - Adult            224
#               Special Event            169
#               Street Event              18
#               Farmers Market             6
#               Plaza Event                6
#               Block Party                5
#               Parade                     3
#               Health Fair                2
#               Open Culture               1
#               Religious Event            1
#               Single Block Festival      1
#               Street Festival            1

# %%
bronx_grouped_by = df_event_range[df_event_range['Event Borough'] == 'Bronx'].groupby(['Event Borough'])['Event Type'].value_counts()
df_bronx_grouped_by = pd.DataFrame(bronx_grouped_by)
df_bronx_grouped_by = df_bronx_grouped_by.rename({'Event Type': 'Count'},axis=1)
df_bronx_grouped_by.sort_values(by='Count', ascending=False)
# Out:
#                                      Count
# Event Borough Event Type
# Bronx         Sport - Youth            360
#               Special Event            126
#               Sport - Adult             42
#               Street Event               8
#               Farmers Market             6
#               Sidewalk Sale              4
#               Athletic Race / Tour       2
#               Single Block Festival      2
#               Block Party                1
#               Parade                     1
#               Stickball                  1

# %%
staten_island_grouped_by = df_event_range[df_event_range['Event Borough'] == 'Staten Island'].groupby(['Event Borough'])['Event Type'].value_counts()
df_staten_island_grouped_by = pd.DataFrame(staten_island_grouped_by)
df_staten_island_grouped_by = df_staten_island_grouped_by.rename({'Event Type': 'Count'},axis=1)
df_staten_island_grouped_by.sort_values(by='Count', ascending=False)
# Out:
#                              Count
# Event Borough Event Type
# Staten Island Special Event    150
#               Sport - Youth    134
#               Sport - Adult     36
#               Block Party        5
#               Street Event       2

# %%
turnstiles_df = df

# %%
stations = pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
stations.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA ADA Notes
# 0      -73.912034                     NaN             Manhattan    0       NaN
# 1      -73.917843            Ditmars Blvd             Manhattan    1       NaN
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan    0       NaN

# %%
stations["STATION"] = stations["Stop Name"].str.strip().str.strip(".").str.upper()
stations.drop_duplicates(subset ="STATION",
                     keep = "first", inplace = True)
stations = stations.sort_values("STATION")
turnstiles_df = turnstiles_df.sort_values("STATION")

# %%
turnstiles_df.drop(turnstiles_df.index[turnstiles_df['STATION'] == '14TH STREET'], inplace = True)
turnstiles_df["STATION"] = turnstiles_df["STATION"].str.strip().str.strip(".").str.upper()
stations["STATION"] = turnstiles_df["STATION"].unique().copy()

# %%
stations_borough = stations[["STATION", "Borough"]]
stations_borough = stations_borough.replace({"Borough" : {"M" : "Manhattan", "Q" : "Queens",
                                                          "Bx" : "Bronx", "Bk" : "Brooklyn",
                                                          "SI" : "Staten Island"}}, regex = True)

# %%
stations_borough_totals = pd.merge(turnstiles_df, stations_borough, on = "STATION")
stations_borough_totals
# Out:
#            C/A  UNIT       SCP    STATION LINENAME DIVISION       DATE  \
# 0        H007A  R248  02-00-01       1 AV        L      BMT 2021-07-22
# 1         H008  R248  01-00-01       1 AV        L      BMT 2021-08-22
# 2         H008  R248  01-00-01       1 AV        L      BMT 2021-08-22
# 3         H008  R248  01-00-01       1 AV        L      BMT 2021-08-23
# 4         H008  R248  01-00-01       1 AV        L      BMT 2021-08-23
# ...        ...   ...       ...        ...      ...      ...        ...
# 2703314   R419  R326  00-00-00  ZEREGA AV        6      IRT 2021-09-17
# 2703315   R419  R326  00-00-00  ZEREGA AV        6      IRT 2021-09-17
# 2703316   R419  R326  00-00-01  ZEREGA AV        6      IRT 2021-09-11
# 2703317   R419  R326  00-00-00  ZEREGA AV        6      IRT 2021-09-16
# 2703318   R419  R326  00-03-01  ZEREGA AV        6      IRT 2021-08-22
#
#              TIME     DESC  ENTRIES  \
# 0        20:00:00  REGULAR   214917
# 1        16:00:00  REGULAR  2862647
# 2        20:00:00  REGULAR  2862661
# 3        00:00:00  REGULAR  2862681
# 4        04:00:00  REGULAR  2862686
# ...           ...      ...      ...
# 2703314  17:00:00  REGULAR   197051
# 2703315  21:00:00  REGULAR   197083
# 2703316  01:00:00  REGULAR   248407
# 2703317  05:00:00  REGULAR   196683
# 2703318  21:00:00  REGULAR  1292038
#
#          EXITS                                                                 \
# 0                                                    54044
# 1                                                 16703670
# 2                                                 16703808
# 3                                                 16703879
# 4                                                 16703911
# ...                                                    ...
# 2703314                                             816004
# 2703315                                             816282
# 2703316                                             412819
# 2703317                                             814631
# 2703318                                             253022
#
#            Borough
# 0        Manhattan
# 1        Manhattan
# 2        Manhattan
# 3        Manhattan
# 4        Manhattan
# ...            ...
# 2703314      Bronx
# 2703315      Bronx
# 2703316      Bronx
# 2703317      Bronx
# 2703318      Bronx
#
# [2703319 rows x 12 columns]

# %%
stations_borough_totals_mini = stations_borough_totals[['STATION','Borough','ENTRIES','DATE']].copy()

stations_borough_totals_mini
# Out:
#            STATION    Borough  ENTRIES       DATE
# 0             1 AV  Manhattan   214917 2021-07-22
# 1             1 AV  Manhattan  2862647 2021-08-22
# 2             1 AV  Manhattan  2862661 2021-08-22
# 3             1 AV  Manhattan  2862681 2021-08-23
# 4             1 AV  Manhattan  2862686 2021-08-23
# ...            ...        ...      ...        ...
# 2703314  ZEREGA AV      Bronx   197051 2021-09-17
# 2703315  ZEREGA AV      Bronx   197083 2021-09-17
# 2703316  ZEREGA AV      Bronx   248407 2021-09-11
# 2703317  ZEREGA AV      Bronx   196683 2021-09-16
# 2703318  ZEREGA AV      Bronx  1292038 2021-08-22
#
# [2703319 rows x 4 columns]

# %% [markdown]
# #### Total entries in each borough for the last 3 months, get the ratio of entries

# %%
total_entries_borough = stations_borough_totals.groupby(['Borough'])['ENTRIES'].sum()
total_entries_borough
# Out:
# Borough
# Bronx            23924221361545
# Brooklyn         28914392186046
# Manhattan        38357192891070
# Queens           17535836831891
# Staten Island     4277084509164
# Name: ENTRIES, dtype: int64

# %%
plt.title("Total entries for each borough for the last 3 months",fontsize=20)
total_entries_borough_image = total_entries_borough.plot(kind='bar',figsize=(20,10),fontsize=16)

plt.savefig('total_entries_borough_image.png', dpi=300, bbox_inches='tight')

# %%
# %whos
# Out:
# Variable                         Type             Data/Info
# -----------------------------------------------------------
# boroughs                         ndarray          5: 5 elems, type `object`, 40 bytes
# bronx_grouped_by                 Series           Event Borough  Event Type<...> Event Type, dtype: int64
# brooklyn_grouped_by              Series           Event Borough  Event Type<...> Event Type, dtype: int64
# col                              str              Start Date
# colors                           list             n=5
# concant                          function         <function concant at 0x7ff6510ed820>
# data                             Series           0     699\n1     216\n2  <...>Name: Count, dtype: int64
# date_range                       DatetimeIndex    DatetimeIndex(['2021-06-3<...>atetime64[ns]', freq='M')
# datetime                         type             <class 'datetime.datetime'>
# df                               DataFrame                  C/A  UNIT      <...>724418 rows x 11 columns]
# df_bronx_grouped_by              DataFrame                                 <...>ckball                  1
# df_brooklyn_grouped_by           DataFrame                                 <...>eet Festival            1
# df_event                         DataFrame               Event ID          <...>[26067 rows x 11 columns]
# df_event_range                   DataFrame               Event ID          <...>n[4883 rows x 11 columns]
# df_manhattan_grouped_by          DataFrame                                 <...>                        1
# df_queens_grouped_by             DataFrame                                 <...>eet Festival            1
# df_staten_island_grouped_by      DataFrame                                 <...>     Street Event       2
# event_locations                  ndarray          3523: 3523 elems, type `object`, 28184 bytes
# event_type                       ndarray          23: 23 elems, type `object`, 184 bytes
# events_date                      Series           2021-09-25    1299\n2021-<...>t Date/Time, dtype: int64
# events_type_count                Series           Sport - Youth            <...> Event Type, dtype: int64
# generate_dates                   function         <function generate_dates at 0x7ff6510eddc0>
# grouped_by_date                  DataFrame                    Event Type\nS<...>1\n2021-09-27         748
# indexed_df_brooklyn_grouped_by   DataFrame           Event Borough         <...>   Street Festival      1
# indexed_most_event_type          DataFrame                 Month           <...> in and Load Outs       7
# labels                           Series           0             Sport - You<...>Event Type, dtype: object
# manhattan_grouped_by             Series           Event Borough  Event Type<...> Event Type, dtype: int64
# mask                             Series           0        False\n1        <...>ength: 26067, dtype: bool
# most_event_type                  DataFrame                                 <...> in and Load Outs       7
# np                               module           <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# pct_missing                      float64          0.0
# pd                               module           <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plt                              module           <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# queens_grouped_by                Series           Event Borough  Event Type<...> Event Type, dtype: int64
# sns                              module           <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# staten_island_grouped_by         Series           Event Borough  Event Type<...> Event Type, dtype: int64
# stations                         DataFrame             Station ID  Complex <...>\n[378 rows x 16 columns]
# stations_borough                 DataFrame                     STATION    B<...>n\n[378 rows x 2 columns]
# stations_borough_totals          DataFrame                   C/A  UNIT     <...>703319 rows x 12 columns]
# stations_borough_totals_mini     DataFrame                   STATION    Bor<...>2703319 rows x 4 columns]
# timedelta                        type             <class 'datetime.timedelta'>
# total_entries_borough            Series           Borough\nBronx           <...>me: ENTRIES, dtype: int64
# turnstiles_df                    DataFrame                  C/A  UNIT      <...>703319 rows x 11 columns]

# %%
df_event_range.columns
# Out:
# Index(['Event ID', 'Event Name', 'Start Date/Time', 'End Date/Time',
#        'Event Agency', 'Event Type', 'Event Borough', 'Event Location',
#        'Community Board', 'Police Precinct', 'Start Date'],
#       dtype='object')

# %%
df_event_range_mini = df_event_range[['Event Name','Event Type','Event Borough','Start Date']].copy()
df_event_range_mini
# Out:
#                                      Event Name        Event Type  \
# 15703                  MoMA PS1 Temporary Plaza      Street Event
# 25663               Covid-19 Vaccination center  Production Event
# 25132               Covid-19 Vaccination Center  Production Event
# 20421  Mobile COVID-19 Testing and Vaccine Site      Street Event
# 705    Mobile COVID-19 Testing and Vaccine Site      Street Event
# ...                                         ...               ...
# 7962                    Soccer - Non Regulation     Sport - Youth
# 4004                    Soccer - Non Regulation     Sport - Youth
# 14712                                    Tennis     Sport - Youth
# 13199                                Basketball     Sport - Youth
# 8068            Football Ã¢â¬â Flag Football     Sport - Youth
#
#       Event Borough Start Date
# 15703        Queens 2021-07-03
# 25663      Brooklyn 2021-07-21
# 25132      Brooklyn 2021-07-21
# 20421     Manhattan 2021-08-06
# 705       Manhattan 2021-08-17
# ...             ...        ...
# 7962       Brooklyn 2021-09-27
# 4004         Queens 2021-09-27
# 14712        Queens 2021-09-27
# 13199        Queens 2021-09-27
# 8068       Brooklyn 2021-09-27
#
# [4883 rows x 4 columns]

# %% [markdown]
# #### Top 5 stations

# %%
top_5_stations = df.groupby(['STATION'], as_index = False )['ENTRIES'].max()
top_5_stations = pd.DataFrame(top_5_stations)
top_5_stations = top_5_stations.sort_values('ENTRIES', ascending=False)

top_5_stations
top_5_stations.to_csv('top_5_stations.csv')
